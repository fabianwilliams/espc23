# %%
import feedparser
import re
import logging
from bs4 import BeautifulSoup
from datetime import datetime
from typing import Generator
from urllib.parse import urljoin
import requests
import json
from requests.adapters import HTTPAdapter, Retry
from dotenv import load_dotenv
import os
import asyncio
from azure.identity.aio import ClientSecretCredential
from msgraph import GraphServiceClient
from kiota_abstractions.api_error import APIError
from msgraph.generated.models.external_connectors.activity_settings import ActivitySettings
from msgraph.generated.models.external_connectors.display_template import DisplayTemplate
from msgraph.generated.models.external_connectors.external_connection import ExternalConnection
from msgraph.generated.models.external_connectors.item_id_resolver import ItemIdResolver
from msgraph.generated.models.external_connectors.search_settings import SearchSettings
from msgraph.generated.models.external_connectors.url_match_info import UrlMatchInfo
from msgraph.generated.models.external_connectors.schema import Schema
from msgraph.generated.models.external_connectors.property_ import Property_
from msgraph.generated.models.external_connectors.property_type import PropertyType
from msgraph.generated.models.external_connectors.label import Label
from msgraph.generated.models.json import Json

from msgraph.generated.models.external_connectors.access_type import AccessType
from msgraph.generated.models.external_connectors.acl import Acl
from msgraph.generated.models.external_connectors.acl_type import AclType
from msgraph.generated.models.external_connectors.external_activity import (
    ExternalActivity,
)
from msgraph.generated.models.external_connectors.external_activity_type import (
    ExternalActivityType,
)
from msgraph.generated.models.external_connectors.external_item import ExternalItem
from msgraph.generated.models.external_connectors.external_item_content import (
    ExternalItemContent,
)
from msgraph.generated.models.external_connectors.external_item_content_type import (
    ExternalItemContentType,
)
from msgraph.generated.models.external_connectors.identity import Identity
from msgraph.generated.models.external_connectors.identity_type import IdentityType
from msgraph.generated.models.external_connectors.properties import Properties

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Prepare the Data
# ## EXTRACT
# ### Microsoft Graph Public ChangeLog

# %%
#Microsoft Change Log RSS Feed
#https://developer.microsoft.com/en-us/graph/changelog/rss
# Pull in the RSS feed data using Feedparser and then explores the list channels
# https://feedparser.readthedocs.io/en/latest/common-rss-elements.html#accessing-common-channel-elements
msgraphchangelog = feedparser.parse("https://developer.microsoft.com/en-us/graph/changelog/rss")
docs = msgraphchangelog.entries

# %%
## Test the data pull by inpection of a few elements
mclentryone = msgraphchangelog.entries[1]
mclentrytwo = msgraphchangelog.entries[2]

# %%
mclentryone
# Note the ID has beta appended to the GUID we will clean that up with a funciton later on
# Out:
# {'id': '1ab6bfa0-5fd2-4d51-9834-a8cfc0ba637cbeta',
#  'guidislink': False,
#  'tags': [{'term': 'Prod', 'scheme': None, 'label': None},
#   {'term': 'beta', 'scheme': None, 'label': None}],
#  'title': 'Security',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://developer.microsoft.com/en-us/graph/changelog/rss',
#   'value': 'Security'},
#  'summary': '<div>Added <b>microsoftDefenderForIoT</b>, <b>microsoftDefenderForServers</b>, <b>microsoftDefenderForStorage</b>, <b>microsoftDefenderForDNS</b>, <b>microsoftDefenderForDatabases</b>, <b>microsoftDefenderForContainers</b>, <b>microsoftDefenderForNetwork</b>, <b>microsoftDefenderForAppService</b>, <b>microsoftDefenderForKeyVault</b>, <b>microsoftDefenderForResourceManager</b> and <b>microsoftDefenderForApiManagement</b> members to the <b>detectionSource</b> enumeration.</div>',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://developer.microsoft.com/en-us/graph/changelog/rss',
#   'value': '<div>Added <b>microsoftDefenderForIoT</b>, <b>microsoftDefenderForServers</b>, <b>microsoftDefenderForStorage</b>, <b>microsoftDefenderForDNS</b>, <b>microsoftDefenderForDatabases</b>, <b>microsoftDefenderForContainers</b>, <b>microsoftDefenderForNetwork</b>, <b>microsoftDefenderForAppService</b>, <b>microsoftDefenderForKeyVault</b>, <b>microsoftDefenderForResourceManager</b> and <b>microsoftDefenderForApiManagement</b> members to the <b>detectionSource</b> enumeration.</div>'},
#  'published': 'Wed, 08 Nov 2023 08:39:06 Z',
#  'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=8, tm_hour=8, tm_min=39, tm_sec=6, tm_wday=2, tm_yday=312, tm_isdst=0)}

# %%
mclentrytwo
# Note the ID has v1.0 appended to the GUID we will clean that up with a funciton later on
# Out:
# {'id': '2ffb1cd0-70b3-4e55-b5f2-b7e6c7d62dc2v1.0',
#  'guidislink': False,
#  'tags': [{'term': 'Prod', 'scheme': None, 'label': None},
#   {'term': 'v1.0', 'scheme': None, 'label': None}],
#  'title': 'Security',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://developer.microsoft.com/en-us/graph/changelog/rss',
#   'value': 'Security'},
#  'summary': '<div>Added <b>microsoftDefenderForIoT</b>, <b>microsoftDefenderForServers</b>, <b>microsoftDefenderForStorage</b>, <b>microsoftDefenderForDNS</b>, <b>microsoftDefenderForDatabases</b>, <b>microsoftDefenderForContainers</b>, <b>microsoftDefenderForNetwork</b>, <b>microsoftDefenderForAppService</b>, <b>microsoftDefenderForKeyVault</b>, <b>microsoftDefenderForResourceManager</b> and <b>microsoftDefenderForApiManagement</b> members to the <b>detectionSource</b> enumeration.</div>',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://developer.microsoft.com/en-us/graph/changelog/rss',
#   'value': '<div>Added <b>microsoftDefenderForIoT</b>, <b>microsoftDefenderForServers</b>, <b>microsoftDefenderForStorage</b>, <b>microsoftDefenderForDNS</b>, <b>microsoftDefenderForDatabases</b>, <b>microsoftDefenderForContainers</b>, <b>microsoftDefenderForNetwork</b>, <b>microsoftDefenderForAppService</b>, <b>microsoftDefenderForKeyVault</b>, <b>microsoftDefenderForResourceManager</b> and <b>microsoftDefenderForApiManagement</b> members to the <b>detectionSource</b> enumeration.</div>'},
#  'published': 'Wed, 08 Nov 2023 08:39:06 Z',
#  'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=8, tm_hour=8, tm_min=39, tm_sec=6, tm_wday=2, tm_yday=312, tm_isdst=0)}

# %%
# Count the number of items (entries) in the feed
num_items = len(msgraphchangelog.entries)
print(num_items)
# Out:
# 1749

# %% [markdown]
# ## Helper Functions needed in TRANSFORM stage later on for External Item

# %%
def remove_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

# %%
def remove_lastfourinid(input_string):
    input_string = input_string[:-4]
    return input_string

# %%
def convert_to_iso8601(date_str):
    # Parse the date string to datetime object
    dt = datetime.strptime(date_str, '%a, %d %b %Y %H:%M:%S Z')

    # Convert to ISO 8601 format
    iso8601_format = dt.isoformat() + "Z"  # Appending 'Z' to indicate UTC
    return iso8601_format

# %%
def create_narrative(id,pd,tit,dscr):
    cleanId = remove_lastfourinid(id)
    dl = f"https://developer.microsoft.com/en-us/graph/changelog/?search={cleanId}"
    cleanDate = convert_to_iso8601(pd)
    narrative = f"On {cleanDate} {tit} entered {dscr} with deeplink {dl}"
    return narrative

# %% [markdown]
# ## Create Connection to Microsoft Graph
# ### Setting up the Client

# %%
credential = ClientSecretCredential(
    os.getenv("TENANT_ID"),
    os.getenv("CLIENT_ID"),
    os.getenv("CLIENT_SECRET")
)
scopes = ['https://graph.microsoft.com/.default']
client = GraphServiceClient(credentials=credential, scopes=scopes)

# %%
# Get the User ID needed as PerformedBy Identity
user_id = os.getenv("USER_ID")

# %% [markdown]
# ## Create the Graph Custom Connector
# ### External Connection

# %%
external_connection = ExternalConnection(
    id="fabsgclpython1",
    name="FabsGraphChangeLog Alpha",
    description="The official Microsoft Graph ChangeLog - Injested in Graph Connector for Copilot",
    activity_settings=ActivitySettings(
        url_to_item_resolvers=[
            ItemIdResolver(
                odata_type="#microsoft.graph.externalConnectors.itemIdResolver",
                priority=1,
                item_id="{slug}",
                url_match_info=UrlMatchInfo(
                    base_urls=[
                        "https://developer.microsoft.com/en-us/graph/changelog"
                    ],
                    url_pattern="/(?<slug>[^/]+)"
                )
            )
        ]
    ),
    search_settings=SearchSettings(
      search_result_templates=[
        DisplayTemplate(
            id="fabsgclpython1",
            priority=1
        )
      ]
    )
)

# %%
schema = Schema(
  base_type="microsoft.graph.externalItem",
  properties=[
    Property_(
        name="title",
        type=PropertyType.String,
        is_queryable=True,
        is_searchable=True,
        is_retrievable=True,
        labels=[
            Label.Title
        ]
    ),
    Property_(
        name="excerpt",
        type=PropertyType.String,
        is_queryable=True,
        is_searchable=True,
        is_retrievable=True
    ),
    Property_(
        name="imageUrl",
        type=PropertyType.String,
        is_retrievable=True
    ),
    Property_(
        name="url",
        type=PropertyType.String,
        is_retrievable=True,
        labels=[
            Label.Url
        ]
    ),
    Property_(
        name="publishdate",
        type=PropertyType.DateTime,
        is_queryable=True,
        is_retrievable=True,
        is_refinable=True,
        labels=[
            Label.LastModifiedDateTime
        ]
    ),
    Property_(
        name="tags",
        type=PropertyType.StringCollection,
        is_queryable=True,
        is_retrievable=True,
        is_refinable=True
    )
  ]
)

# %% [markdown]
# ## Functions to Create Connection and Schema
# #### resultLayout.json is the Adaptive Card that will render in the Verticals in Search

# %%
async def _create_connection():
    print("Creating connection...")
    with open("resultLayout.json", "r", encoding='utf-8') as file:
        adaptive_card = file.read()
        layout = json.loads(adaptive_card)

        assert external_connection.search_settings is not None
        assert external_connection.search_settings.search_result_templates is not None

        external_connection.search_settings.search_result_templates[0].layout = Json(
            additional_data=layout
        )

    await client.external.connections.post(external_connection)
    print("CONNECTION CREATION DONE")

# %%
async def _create_schema():
    print("Creating schema...")

    assert external_connection.id is not None
    await client.external.connections.by_external_connection_id(external_connection.id).schema.patch(schema)
    print("DONE")

# %%
# Function below executes both and will create the Connection and Schema

# %%
async def create_connection():
    await _create_connection()
    await _create_schema()

# %%
#Run the Connection Setup Process as a Function
#As of now this will throw an error at the very end due to a bug in the SDK
#The Connection and Schema will be created successfully but the return code is broken in the SDK
#it has been reported and a PR is underway
createpoc1conn = await create_connection()
# Out:
# Creating connection...
# CONNECTION CREATION DONE
# Creating schema...
# ---------------------------------------------------------------------------
# DeserializationError                      Traceback (most recent call last)
# Cell In[25], line 5
#       1 #Run the Connection Setup Process as a Function
#       2 #As of now this will throw an error at the very end due to a bug in the SDK
#       3 #The Connection and Schema will be created successfully but the return code is broken in the SDK
#       4 #it has been reported and a PR is underway
# ----> 5 createpoc1conn = await create_connection()
#
# Cell In[24], line 3, in create_connection()
#       1 async def create_connection():
#       2     await _create_connection()
# ----> 3     await _create_schema()
#
# Cell In[22], line 5, in _create_schema()
#       2 print("Creating schema...")
#       4 assert external_connection.id is not None
# ----> 5 await client.external.connections.by_external_connection_id(external_connection.id).schema.patch(schema)
#       6 print("DONE")
#
# File ~/anaconda3/envs/espc/lib/python3.11/site-packages/msgraph/generated/external/connections/item/schema/schema_request_builder.py:92, in SchemaRequestBuilder.patch(self, body, request_configuration)
#      89     raise Exception("Http core is null")
#      90 from .....models.external_connectors.schema import Schema
# ---> 92 return await self.request_adapter.send_async(request_info, Schema, error_mapping)
#
# File ~/anaconda3/envs/espc/lib/python3.11/site-packages/kiota_http/httpx_request_adapter.py:176, in HttpxRequestAdapter.send_async(self, request_info, parsable_factory, error_map)
#     174 if self._should_return_none(response):
#     175     return None
# --> 176 root_node = await self.get_root_parse_node(response, parent_span, parent_span)
#     177 _deserialized_span = self._start_local_tracing_span("get_object_value", parent_span)
#     178 value = root_node.get_object_value(parsable_factory)
#
# File ~/anaconda3/envs/espc/lib/python3.11/site-packages/kiota_http/httpx_request_adapter.py:396, in HttpxRequestAdapter.get_root_parse_node(self, response, parent_span, attribute_span)
#     394     response_content_type = self.get_response_content_type(response)
#     395     if not response_content_type:
# --> 396         raise DeserializationError("No response content type found for deserialization")
#     397     return self._parse_node_factory.get_root_parse_node(response_content_type, payload)
#     398 finally:
#
# DeserializationError: No response content type found for deserialization

# %%
#verify that the Microsoft Graph External Connector has been created
print(external_connection.id)
# Out:
# fabsgclpython1

# %%
# BREAK IN CASE OF FIRE
# Use this to delete the connection and start over
#await client.external.connections.by_external_connection_id(external_connection.id).delete()

# %% [markdown]
# # Create the External Item
# ## This is the TRANSFORM and LOAD Stage

# %% [markdown]
# ### Functions to Transform and Load

# %%
def _transform(content) -> Generator[ExternalItem, None, None]:
    # needed to properly format activity date
    local_time_with_timezone = datetime.now().astimezone()

    for logentry in msgraphchangelog.entries:
        #print(logentry["published"])
        cleanDate = convert_to_iso8601(logentry.published)
        cleanId = remove_lastfourinid(logentry.id)
        dl = f"https://developer.microsoft.com/en-us/graph/changelog/?search={cleanId}"
        content = create_narrative(logentry.id, logentry.published, logentry.title, logentry.description)
        currentnarrative = remove_html_tags(logentry.description)
        yield ExternalItem(
            id=remove_lastfourinid(logentry.id),
            properties=Properties(
                additional_data={
                    "title": logentry.title,
                    "excerpt": currentnarrative,
                    "imageUrl": "https://raw.githubusercontent.com/microsoftgraph/g-raph/master/g-raph.png",
                    "url": dl,
                    "publishdate": cleanDate
                }
            ),
            content=ExternalItemContent(
                type=ExternalItemContentType.Html, value=content
            ),
            acl=[
                Acl(
                    type=AclType.Everyone,
                    value="everyone",
                    access_type=AccessType.Grant,
                )
            ],
            activities=[
                ExternalActivity(
                    odata_type="#microsoft.graph.externalConnectors.externalActivity",
                    type=ExternalActivityType.Created,
                    start_date_time=cleanDate,
                    performed_by=Identity(type=IdentityType.User, id=user_id),
                )
            ],
        )

# %%
async def _load(content: Generator[ExternalItem, None, None]):
    for doc in content:
        try:
            print("Loading %s...", doc.id)
            assert external_connection.id is not None
            #Below print is for display purpoes only for the sake of the demo and leave behind
            #It can be lengthy based on the amount of indexed item. consider commenting out
            #print("Doc...", doc)
            assert doc.id is not None

            await client.external.connections.by_external_connection_id(
                external_connection.id
            ).items.by_external_item_id(doc.id).put(doc)
            print("DONE loading")
        except Exception as e:
            print("Failed to load %s: %s", doc.id, e)
            return

# %% [markdown]
# ### Do the Transform

# %%
transformed = _transform(msgraphchangelog.entries)

# %% [markdown]
# ### Do the Load
# #### For me this takes 1/2 hour for 1700 items

# %%
loadChangeLog = await _load(transformed)
# Out:
# Loading %s... 97796aeb-ce8a-4650-ad43-6872cee08c4d
# DONE loading
# Loading %s... 1ab6bfa0-5fd2-4d51-9834-a8cfc0ba637c
# DONE loading
# Loading %s... 2ffb1cd0-70b3-4e55-b5f2-b7e6c7d62dc2
# DONE loading
# Loading %s... 400279c6-8c1b-4a1d-92ff-c49987587f79
# DONE loading
# Loading %s... 8fefbf46-97c3-43c7-96a9-56c1f4c24052
# DONE loading
# Loading %s... e70ef0dd-ac40-4549-9583-958a7a9c0b66
# DONE loading
# Loading %s... 514fea21-1d51-46d0-847e-9c2cce1d6c58
# DONE loading
# Loading %s... 8b9db607-81fd-4013-af2e-d6cb709aa313
# DONE loading
# Loading %s... cc0c0a79-a691-485d-b47c-8b0ee543ae6c
# DONE loading
# Loading %s... 7a1f574d-c348-4ce9-890b-d55b58b2d3c2
# DONE loading
# Loading %s... 2204d5d0-d3cf-4850-88b7-d430ab574476
# DONE loading
# Loading %s... bbb70cce-5252-40be-a7ca-7c29f99cb089
# DONE loading
# Loading %s... a12d7c65-273a-4409-8c5a-a8be6bcfd005
# DONE loading
# Loading %s... 71ebad7b-fc20-4469-b895-ddeef0ee54a0
# DONE loading
# Loading %s... 14a780c1-d222-4476-acc0-3c5b6425f040
# DONE loading
# Loading %s... c1808556-a3ee-4258-a706-e1dc6ab234bf
# DONE loading
# Loading %s... 672c60ca-5ad4-4a2a-a158-37a999e02d27
# DONE loading
# Loading %s... f790cf16-283a-4044-bd17-a6a7c72bdf38
# DONE loading
# Loading %s... c5c0d0a3-0996-4d62-9150-e9b789ce02b4
# DONE loading
# Loading %s... 80aec7bf-811c-46b9-bb97-9db36b618153
# DONE loading
# Loading %s... 9b4cd317-0b73-42e2-991a-9654e292f8a0
# DONE loading
# Loading %s... 98e8900a-08f5-4ab0-ba16-8d7c9cc5d6ef
# DONE loading
# Loading %s... dbe9e6bd-57ef-430e-b9a6-3669472052da
# DONE loading
# Loading %s... 260527bf-7d67-490c-a732-521065078560
# DONE loading
# Loading %s... be053170-38ef-40c5-a2bd-4e1e2db5a1e7
# DONE loading
# Loading %s... 2b4cd7a5-2095-4ca3-80b0-da96df6c7e90
# DONE loading
# Loading %s... 1cff7962-ce78-4d66-bcdf-94ee18c27c2b
# DONE loading
# Loading %s... 2795003f-a59e-4944-9c52-6dcee39bacdb
# DONE loading
# Loading %s... a7fdcd96-5c33-4208-9031-f8e62c27c1bf
# DONE loading
# Loading %s... a7fdcd96-5c33-4208-9031-f8e62c27c1bf
# DONE loading
# Loading %s... a9a67281-e206-43ef-92d1-ad9375b97d1b
# DONE loading
# Loading %s... 6f211280-ef11-487b-b98a-fe6eec64ea7b
# DONE loading
# Loading %s... b0fdba93-efca-407d-b7fc-12e792ece3f6
# DONE loading
# Loading %s... 79a3808d-826e-431f-9288-58144fe2776a
# DONE loading
# Loading %s... 12f93700-b666-4c5c-b569-7db20691c5b3
# DONE loading
# Loading %s... bfd0c33a-af94-4b3a-867d-a904d3986b0f
# DONE loading
# Loading %s... 8c297080-41ec-436e-9907-f0f8a3ee036d
# DONE loading
# Loading %s... c2ff9eba-b803-4557-94dd-282769f9016e
# DONE loading
# Loading %s... cd506d8f-eddb-4d12-859d-a7894452989e
# DONE loading
# Loading %s... 931b4c70-9941-46b8-8afd-59138523c03e
# DONE loading
# Loading %s... 80297d8c-5457-4fa1-be2b-769490b818bb
# DONE loading
# Loading %s... 3fdf4a8e-0ba7-405a-91d1-f7b4b6ac6983
# DONE loading
# Loading %s... ac7992ce-3a29-456a-88b9-934313fdd0ea
# DONE loading
# Loading %s... 09e85d0c-2551-40e7-a037-1f36fade0b0b
# DONE loading
# Loading %s... 26b75f44-c3c8-4300-a98b-2ee6c75e6146
# DONE loading
# Loading %s... c022f245-26dd-4fd7-81f2-4297d5a37c6d
# DONE loading
# Loading %s... 541c1216-7521-4a72-ac7e-7c9ab9c46e69
# DONE loading
# Loading %s... 4d35dcf2-2f6c-413d-a4c4-c7770152a77b
# DONE loading
# Loading %s... 6ec2ebe8-8f0c-4595-a8bb-5a40c631fcb8
# DONE loading
# Loading %s... bb202bf3-3029-4b9a-b1be-8df926dbb45e
# DONE loading
# Loading %s... 3984db43-19bc-4257-bfc2-38c30d8462f3
# DONE loading
# Loading %s... 840dd994-b26b-48a2-8d7c-1b52ea86a45c
# DONE loading
# Loading %s... a8aa5b98-5fb3-4aba-acec-5e85209a4026
# DONE loading
# Loading %s... e0bcac9c-8d0e-4b23-8bbf-e50150848d35
# DONE loading
# DONE loading
# Loading %s... c9f8d9b0-da32-48d1-9980-06c1ac95b815
# DONE loading
# Loading %s... b6aab1b1-6ba2-470c-85e6-a5b700bca26b
# DONE loading
# Loading %s... d04de9d7-6b93-4ae5-ba1a-a91f8b159ad0
# DONE loading
# Loading %s... 8f05b5ef-fbdd-4990-a11f-ed8493585072
# DONE loading
# Loading %s... 742d05f5-7c66-4398-add8-e53e4c45c5b9
# DONE loading
# Loading %s... a64b8d10-4143-415b-b851-be687b11005d
# DONE loading
# Loading %s... caa9fb73-da66-4a9e-8ad8-b6aeb478195c
# DONE loading
# Loading %s... 0d0ccba4-794b-46b6-be6b-5761eef57e0c
# DONE loading
# Loading %s... 3f365793-7526-4ce7-816b-ad1f7bba3eb4
# DONE loading
# Loading %s... 3d55601a-1632-4115-9e52-4d8a174040d4
# DONE loading
# Loading %s... b6dc9e4b-3c6d-4946-be20-90fac94839c2
# DONE loading
# Loading %s... 6b0952c8-afd7-4a0e-a915-f200d946d36c
# DONE loading
# Loading %s... f0a17833-664d-4de4-9295-1f463250e747
# DONE loading
# Loading %s... 0b023547-c61c-46df-a15c-a79570c6a0f6
# DONE loading
# Loading %s... f65a6785-6042-4258-b9a4-385cfb2eb5d2
# DONE loading
# Loading %s... b3449cc1-39ed-4498-80ba-7edb3402101e
# DONE loading
# Loading %s... 39ecd7a5-d43c-4bea-b7ef-53d022554b4e
# DONE loading
# Loading %s... ab71be33-ee9d-4a1e-bf06-0133911ad680
# DONE loading
# Loading %s... 5997e838-8b68-4ef5-9298-c5d9dac95add
# DONE loading
# Loading %s... 5008c515-c75e-4cc9-b436-4b42133cb927
# DONE loading
# Loading %s... d118dbd4-557f-4d18-8ff1-4659d6868a01
# DONE loading
# Loading %s... fb9eeb9e-adf8-43f6-8aee-7a55853c74a5
# DONE loading
# Loading %s... c450f46a-46a4-4198-b81e-8514ee65377f
# DONE loading
# Loading %s... e66d855d-9635-4fbb-b435-23182467f0ce
# DONE loading
# Loading %s... 7a36d6d3-232d-4ddc-b3d4-43cf2672c217
# DONE loading
# Loading %s... b023fd62-6131-49c4-bd7d-12b3f84e2317
# DONE loading
# Loading %s... 3d99b5f0-e0dd-4a84-a278-b8afa35e33fc
# DONE loading
# Loading %s... 3f3d03df-a0c3-4d63-82b9-4bc912be0152
# DONE loading
# Loading %s... 939f058a-8f58-4a85-9b45-90fe16b62ee2
# DONE loading
# Loading %s... d9c669e9-66a4-4453-89e8-2628acdd1fbe
# DONE loading
# Loading %s... a244d924-f4ee-4f19-9e2d-a5a900ba82e5
# DONE loading
# Loading %s... 33faed78-3754-43a7-a08a-4d6c9d5d741f
# DONE loading
# Loading %s... 7cd18c8c-0160-47ce-a87c-bb90f3d67212
# DONE loading
# Loading %s... 7ffca2c2-e102-44b9-a5d8-966f35064056
# DONE loading
# Loading %s... bb7f0809-9061-4b82-b872-249661a3d329
# DONE loading
# Loading %s... 9e91b305-975d-46fa-b322-88e522ed5256
# DONE loading
# Loading %s... 2bbb372e-272d-401a-9bab-0c1b6e38977f
# DONE loading
# Loading %s... d140e1fa-9488-4922-9b71-4f75148cf1e0
# DONE loading
# Loading %s... 7b6aebb5-6126-4f2d-b4c4-e0952613719b
# DONE loading
# Loading %s... 6248c9ab-afef-4d70-81e8-7eb948a3a45b
# DONE loading
# Loading %s... 3c3a58d9-3161-414b-968e-74023127664d
# DONE loading
# Loading %s... 2004c955-fd84-4997-83da-10d8c5cd370c
# DONE loading
# Loading %s... bebbf84c-73de-4070-b44f-c670c25c4d4f
# DONE loading
# Loading %s... 59abcc02-0b31-48a0-a44b-052a3d123267
# DONE loading
# Loading %s... fad6f62b-fdc9-462f-ac1a-d3ea2b860fce
# DONE loading
# Loading %s... 9e2c3005-90b3-4f99-80bc-7cb5b5ccfb92
# DONE loading
# Loading %s... 0a697e64-e12c-40ac-b133-a0faeab783c4
# DONE loading
# Loading %s... b084b945-0968-4615-b2d7-0a61e3a02a55
# DONE loading
# Loading %s... 00e2bcb5-13bf-4da2-8005-50925ca028e2
# DONE loading
# Loading %s... b4b74b54-7d92-4001-9706-04f2892d4bfd
# DONE loading
# Loading %s... c9cb7b4d-85b0-4fa8-9028-9b8235f3b9b2
# DONE loading
# Loading %s... 48004467-2fa8-4cd8-959f-88616321cf4b
# DONE loading
# Loading %s... 27b55466-1caa-42c1-9a31-2e49a8380d9d
# DONE loading
# Loading %s... 47c39c44-62a7-4e82-964d-6044de76f128
# DONE loading
# Loading %s... f5cc2d2b-925e-47cc-865d-5713fdace6b9
# DONE loading
# Loading %s... f1a2366e-c693-4a6d-8783-370f38cd9660
# DONE loading
# Loading %s... 2107ee19-7ed3-4480-936c-61a372e36751
# DONE loading
# Loading %s... afc883f0-3a47-4e02-bcb1-3c7be4a5cdf2
# DONE loading
# Loading %s... 8a74709d-d633-4cc1-81e2-89a67f4ae290
# DONE loading
# Loading %s... db8cde72-c86c-4a67-9c0f-65663c90d0df
# DONE loading
# Loading %s... 4cc61cac-ef88-4767-a4c5-59e80ce208c3
# DONE loading
# Loading %s... d07006c1-a451-4fcf-b9b6-835546842783
# DONE loading
# Loading %s... 8ca9e51e-a486-41cb-af0e-105f86177d1b
# DONE loading
# Loading %s... 2693683c-f49a-4715-a649-edadd3f54aad
# DONE loading
# Loading %s... 7f321a9a-aa22-4bd3-8390-7739a47b1709
# DONE loading
# Loading %s... daf1f318-9192-4860-b77b-d8766ac97dd4
# DONE loading
# Loading %s... 9765b92a-f3fb-41a2-930b-b4cc506ada62
# DONE loading
# Loading %s... 5b87dca1-1f01-4c0a-8c5d-add65ebe8762
# DONE loading
# Loading %s... 4b2c8f86-11b9-4f0e-9afd-bb43d46db4c2
# DONE loading
# Loading %s... 8a63383f-7189-44dc-bbd0-4c26e4c575ee
# DONE loading
# Loading %s... 91ef0477-1540-4df3-8683-6b2ee18ae17c
# DONE loading
# Loading %s... 989ba92a-5a19-4864-a15a-c1f135776582
# DONE loading
# Loading %s... f6b20371-ca94-44d6-a70c-443f4ae9e653
# DONE loading
# Loading %s... e9e76f8b-a4c0-4e1e-8f49-1c99dfa89219
# DONE loading
# Loading %s... daf6e0cb-5131-4bb5-ae42-0975e3258159
# DONE loading
# Loading %s... 70fbd967-1f31-4c82-8532-8db6ec6e9007
# DONE loading
# Loading %s... 9db01b0d-0295-4f32-ab7a-839aa9606734
# DONE loading
# Loading %s... 47532e4b-a639-48ff-b0bb-aa8bdd5cdf6b
# DONE loading
# Loading %s... d64da901-381d-4cc8-a3fb-a582ef1153c4
# DONE loading
# Loading %s... e998825a-ff8c-4207-baf4-2691323e4a82
# DONE loading
# Loading %s... 1fed1938-c3d6-4ba3-b1c0-79f3a48d6fa7
# DONE loading
# Loading %s... 32581844-a1d3-11ed-a8fc-0242ac120002
# DONE loading
# Loading %s... 42b24db2-6255-4607-af43-9cb97c5230e5
# DONE loading
# Loading %s... f52b3a96-4c8f-44b4-968a-ccc0c3f24a92
# DONE loading
# Loading %s... 692d6f2b-eca3-44ed-8f63-482cbcde242e
# DONE loading
# Loading %s... df105e58-8a6f-47f3-8307-c23aa8b6761a
# DONE loading
# Loading %s... 05DF0873-86C7-4B55-99AB-35AE3A4AFB09
# DONE loading
# Loading %s... 5dd1a692-b492-4bfa-a614-60cc544aafd7
# DONE loading
# Loading %s... d46f7136-1ef8-47e4-b10e-8e31a87d47f4
# DONE loading
# Loading %s... a4a26d2c-47f7-4aa2-9a38-8c979cc811a1
# DONE loading
# Loading %s... 5348d8d7-63da-44f6-a85b-96fe17fe342f
# DONE loading
# Loading %s... 7d081787-a4a6-44e8-a239-52c7782854f1
# DONE loading
# Loading %s... 7b116627-863d-41cd-a828-26d71fe05118
# DONE loading
# Loading %s... c186e5e6-a3eb-4b60-a015-1d9770c08954
# DONE loading
# Loading %s... af2b778c-bcb4-4003-8412-f8b511443dc5
# DONE loading
# Loading %s... 4ad9e0f3-e074-4f8e-a726-d1c4a410e386
# DONE loading
# Loading %s... 5dbe4117-149f-46ce-b26a-5f2c1a581389
# DONE loading
# Loading %s... 5b969eff-9805-406b-afc9-19d7106ce14a
# DONE loading
# Loading %s... ff343287-bb5a-446a-b91f-7ea65d7842db
# DONE loading
# Loading %s... 04f2aadc-7c54-414e-bc3a-d70d78ac4146
# DONE loading
# Loading %s... 66342c44-4bd8-4324-b5f1-5002171a8e51
# DONE loading
# Loading %s... 7208e6e3-6f7d-4490-a27b-c529578f9f8a
# DONE loading
# Loading %s... 79b38947-d95a-41ce-aa48-2394f5d7e1fc
# DONE loading
# Loading %s... 5cbf1eb2-c4fe-44c5-8865-48307d19d3c8
# DONE loading
# Loading %s... c228429d-a285-407d-b2d3-5c24f0565c48
# DONE loading
# Loading %s... 216f8ec6-c6a2-49fc-abff-8d88c19ba8d4
# DONE loading
# Loading %s... 5b493ae4-ecb3-4d95-82a4-df22d19277ac
# DONE loading
# Loading %s... 2a5082bb-51b7-43c3-943f-f71396535ced
# DONE loading
# Loading %s... fcbc337a-37d1-47d7-afc0-5b5fa30324c7
# DONE loading
# Loading %s... 4e3dfeab-32cf-4087-9c82-2354d6f9ae0e
# DONE loading
# Loading %s... 53dcb5cc-6ce2-4c0b-acf3-0b94cff013e3
# DONE loading
# Loading %s... c5cda5a9-625a-436f-8d01-46d646d39b5d
# DONE loading
# Loading %s... 31b20e34-5130-4eec-84c6-7abd2794d009
# DONE loading
# Loading %s... 2f259fea-fe5f-4a3f-984f-80afdebf768d
# DONE loading
# Loading %s... 7032bc3a-d753-4589-9834-4c07d3c89f19
# DONE loading
# Loading %s... 755b97f3-6ac9-4dbd-b74f-57ac7d0e0320
# DONE loading
# Loading %s... 79aa5bce-576b-4533-8085-33bf06bcfcfb
# DONE loading
# Loading %s... 163505d3-b68c-4fc0-b9d5-ec67cd05f574
# DONE loading
# Loading %s... 2b9babe7-efcd-4ddd-9482-df2636ec976e
# DONE loading
# Loading %s... 4dd01e64-4410-46e2-b894-413759981eed
# DONE loading
# Loading %s... 05184a38-79d5-406e-b54d-e28e5ea2ea28
# DONE loading
# Loading %s... 82fb7fe7-4c12-4422-8112-563496de0f33
# DONE loading
# Loading %s... 2a266136-d0ba-48a7-a979-38439d2173a8
# DONE loading
# Loading %s... 523c6227-aa1d-473f-8c16-50fd37ca12c6
# DONE loading
# Loading %s... e5f82c50-922a-40d0-b4ca-c2f248ad4516
# DONE loading
# Loading %s... 75cd8c39-4f8b-467f-aadb-a1b184720427
# DONE loading
# Loading %s... 7fee3720-43ef-4927-8e81-4b8aafe39f0c
# DONE loading
# Loading %s... 4c336ec2-2fa7-42e8-8aea-941251981e93
# DONE loading
# Loading %s... c81d114e-4e16-4699-a780-9e6c411121dc
# DONE loading
# Loading %s... 37e9a406-b8c0-4ae1-a8bf-b1e9d2c0dea6
# DONE loading
# Loading %s... 00c006a9-0eaf-423f-9ed1-ge86808382ab
# DONE loading
# Loading %s... 29495af2-28ab-4012-bd65-215593281a1c
# DONE loading
# Loading %s... 3fed95c9-0780-4973-b481-6aaf7227c340
# DONE loading
# Loading %s... 588cac11-3d88-4e1d-a284-af3b1ceb6cbf
# DONE loading
# Loading %s... 62e788b4-e9ae-42ab-8318-a7732199d52c
# DONE loading
# Loading %s... 90b9b42f-a66a-45b4-bb64-3f85e5045e81
# DONE loading
# Loading %s... 2dca7e8b-c8af-45c1-9fa6-f108e93d8562
# DONE loading
# Loading %s... e7b9b5dc-61ff-472c-960f-08ec52f2e29d
# DONE loading
# Loading %s... ebcb5d06-adbe-48b2-bd6d-46e5f6b3d759
# DONE loading
# Loading %s... 90d99702-fe6e-44c7-a45a-a2ad1442bd22
# DONE loading
# Loading %s... c072ab02-1b08-431a-8d73-649b335dc867
# DONE loading
# Loading %s... 7f706f6a-ee66-49b5-9325-f55149f952ac
# DONE loading
# Loading %s... 7aeadf58-7f96-4a5f-afac-3bb114bdb738
# DONE loading
# Loading %s... a5030551-c01c-40e5-9c01-21055779399a
# DONE loading
# Loading %s... a1532782-8e1f-4dad-9b88-66861b3e2fc5
# DONE loading
# Loading %s... d3e7c7ee-a10d-4a6b-a592-3a6af9b8671f
# DONE loading
# Loading %s... 3e69c76c-3bf7-4008-b81b-d82849f4adab
# DONE loading
# Loading %s... 4f56b8d2-3a5a-46be-9cc4-8f71a796c1c0
# DONE loading
# Loading %s... 1c8087f9-c32f-45bd-b0ee-bfe417d6cd90
# DONE loading
# Loading %s... e458d82b-6b08-430a-a664-3e4d241e978a
# DONE loading
# Loading %s... 02694965-8e9f-459a-ae7a-08d006fdb510
# DONE loading
# Loading %s... be76b629-01ee-4362-976d-088a5d861bb0
# DONE loading
# Loading %s... 04fb09f6-d2b7-48b7-9fd1-72916809de5d
# DONE loading
# Loading %s... 7e7346db-a7e5-40c2-987a-2bbba5076f7b
# DONE loading
# Loading %s... a8aa5b98-5fb3-4aba-acec-5e85209a4026
# DONE loading
# Loading %s... cd4e114e-6354-438a-bde7-b92378954f0c
# DONE loading
# Loading %s... 376c7fac-b9f8-4d4c-b9e4-4e7c8eda2122
# DONE loading
# Loading %s... e393aa08-85ce-4352-9d3b-930bebb43139
# DONE loading
# Loading %s... aec797bc-1676-49bf-a12a-1736503a424b
# DONE loading
# Loading %s... 2994b86c-6ed7-48ed-b7ff-492aa53d2e33
# DONE loading
# Loading %s... 05977d57-f279-432f-b811-ff44dc36ad0c
# DONE loading
# Loading %s... a02cfa95-915d-411a-8acb-557c8d8aa659
# DONE loading
# Loading %s... 1611abed-851f-461b-b351-d242a41a3fe4
# DONE loading
# Loading %s... 09c0c670-3c21-45f3-a5c9-2dd89dbe6aab
# DONE loading
# Loading %s... 89b86683-1457-4b10-bf89-d1af587f4692
# DONE loading
# Loading %s... FA782B9D-526C-403F-AA57-8144A4E736FB
# DONE loading
# Loading %s... 26776B71-9B2E-45A3-B0CD-D6ECF7CF82C3
# DONE loading
# Loading %s... 96E5DE9E-A56A-4FD1-B8E2-23BA9D180975
# DONE loading
# Loading %s... B90040F5-2D0D-4C16-BFA0-EBCD27BD5361
# DONE loading
# Loading %s... 59cd1acf-d56a-4cd3-a213-643cbcc3c3ab
# DONE loading
# Loading %s... b5aef9f7-ffc6-4018-997a-b7f5dcbfe30f
# DONE loading
# Loading %s... 92cd3f93-acde-444e-bc37-bf8edf681d97
# DONE loading
# Loading %s... 0d00d1b1-db8b-490d-b3c2-73ca296139df
# DONE loading
# Loading %s... 9b44d7d0-5380-11ed-bdc3-0242ac120002
# DONE loading
# Loading %s... 00c006a9-0eaf-423f-9ed1-ge86808382ab
# DONE loading
# Loading %s... 8f05250d-ca00-4b15-9488-f6f755a80eae
# DONE loading
# Loading %s... 17f8d8ce-4acb-4ad1-8eea-a6881845bfff
# DONE loading
# Loading %s... 7b4dd650-8f30-470e-a850-93b0f21fd48a
# DONE loading
# Loading %s... bf31e677-d3ae-4c1c-8be3-72900113ccd4
# DONE loading
# Loading %s... 827d51a9-63d6-4d06-a157-262bf134e8d8
# DONE loading
# Loading %s... d8d56f67-839e-42a2-a4f1-e493c1653729
# DONE loading
# DONE loading
# Loading %s... 90b8705c-d9a1-49d0-9769-ffd324961811
# DONE loading
# Loading %s... 3e77b3b8-1396-49ab-b2d0-a26bef7ddb8e
# DONE loading
# Loading %s... b93829d7-509b-43bf-9ff7-b9a17032bae6
# DONE loading
# Loading %s... 19cc5fe8-13f2-4257-93c6-7ff1ca8581d5
# DONE loading
# Loading %s... 87420913-5aab-4181-8ebf-7b4734d76987
# DONE loading
# Loading %s... d980ad13-4f39-4938-9fc0-d8a428aa6000
# DONE loading
# Loading %s... 1e139b6c-35c7-4d54-8d37-cc2e85828db8
# DONE loading
# Loading %s... b888b86c-783d-4a20-8ae4-56293ae23d62
# DONE loading
# Loading %s... 0f5b75ca-75b9-4645-8cd8-eda9f01a3a79
# DONE loading
# Loading %s... 0761fa9b-d6c7-41cb-8f1c-749379d1055d
# DONE loading
# Loading %s... c31056e4-ae34-4a4e-acd3-d660d4a5266c
# DONE loading
# Loading %s... 17dccbf8-ac36-44d2-8c03-90abef046e63
# DONE loading
# Loading %s... 0c77d8f1-df1c-439e-b4c7-4dbdd871c586
# DONE loading
# Loading %s... e2d31838-cc0f-4811-a96d-a699e857d92a
# DONE loading
# Loading %s... f340cb07-80c1-487f-848e-380cb1d397f6
# DONE loading
# Loading %s... 132b2567-f3dd-4036-958e-ae2d53e23ad2
# DONE loading
# Loading %s... 8b0db479-fcd5-4bbc-a9d8-43fb039f6664
# DONE loading
# Loading %s... a185113d-67a1-436c-bda9-a852e696ce41
# DONE loading
# Loading %s... d2ee5435-d64c-4947-99e0-5a1ef8332b38
# DONE loading
# Loading %s... 0b855a64-516c-4b72-aa93-39322a979233
# DONE loading
# Loading %s... dd8cc504-3861-450c-add5-763a11dd0266
# DONE loading
# Loading %s... 7a3d023d-8aa8-438c-afa7-f7f488623deb
# DONE loading
# Loading %s... 5321afac-b6a5-4946-88c0-8d0964aca730
# DONE loading
# Loading %s... 052592b9-ab1c-4782-b19a-04c61c33ef3f
# DONE loading
# Loading %s... 482c20c2-aa5d-4d0c-badd-7c2f3faaddcf
# DONE loading
# Loading %s... bacd077e-b2ee-4d2b-be5d-b4ca0a6bcfe4
# DONE loading
# Loading %s... 9bc3c118-c0b7-43ed-8fa8-679f566fea64
# DONE loading
# Loading %s... a689460b-853f-4cbd-8973-ffd1b9cc1376
# DONE loading
# Loading %s... 62ddc58a-7613-45a9-9380-49e87c64ab00
# DONE loading
# Loading %s... fc6b3cc1-615c-4cea-b88f-07540b3d43da
# DONE loading
# Loading %s... de54d2e0-f6ea-485c-9b8d-85f7b484cddb
# DONE loading
# Loading %s... b4dff39b-4869-4fb7-a274-8929abc049d2
# DONE loading
# Loading %s... 234823ab-d3b3-4ad6-9eab-0db8fe3d93a7
# DONE loading
# Loading %s... a8a72aa0-464c-4b7f-b4d6-266a9e88d716
# DONE loading
# Loading %s... 65c699bb-49cf-4a9d-bee0-7e2950d966a4
# DONE loading
# Loading %s... eaa1c592-65d5-4902-8473-1888a6b4594e
# DONE loading
# Loading %s... e33b35a2-c9d5-405d-8519-a61a32e40e09
# DONE loading
# Loading %s... 787f07b7-7f12-45f6-9681-9eb3909b535e
# DONE loading
# Loading %s... 331f93e1-f1a4-4868-bf74-ee03d0e44599
# DONE loading
# Loading %s... 331f93e1-f1a4-4868-bf74-ee03d0e44599
# DONE loading
# Loading %s... 886555c4-0324-4b07-934f-117bae29157c
# DONE loading
# Loading %s... f30575cf-9eb6-430f-885c-1cec5536d7d7
# DONE loading
# Loading %s... a74bf4db-93a3-4a4c-98b0-400bac1e2131
# DONE loading
# Loading %s... 17c54352-c87f-47fd-ab92-e19ce2da7bcc
# DONE loading
# Loading %s... ce998c71-ecc3-4fe7-adaa-ff6a2ced7cee
# DONE loading
# Loading %s... 249d7bc8-219c-44b5-9738-c1134b4c1e24
# DONE loading
# Loading %s... 80ef6eaa-e6a5-4892-ad09-84307611f60a
# DONE loading
# Loading %s... 35662e55-573c-464e-b999-093a27ff63f7
# DONE loading
# Loading %s... 81de8e8a-4ac0-11ed-b878-0242ac120002
# DONE loading
# Loading %s... 68579e1b-bf41-47ff-8fde-1e32f960b9b8
# DONE loading
# Loading %s... 06a63cc8-a5be-49af-adf7-8c34a822c8d9
# DONE loading
# Loading %s... d1f73ee5-882c-4068-b751-5a3d93329c09
# DONE loading
# Loading %s... 04f199ca-74fe-4c67-b39f-2feacad3f304
# DONE loading
# Loading %s... 1cc8a2c4-49bd-4aa2-ab33-eb82169dc17f
# DONE loading
# Loading %s... 10c162ec-a1ea-4b26-a865-c4d54de08c4a
# DONE loading
# Loading %s... df8951cf-1bb2-4670-ba15-bd95f1e0f44a
# DONE loading
# Loading %s... 4cc4e6b4-85f5-43d7-9adc-71ff0b22553e
# DONE loading
# Loading %s... 853fa7eb-f4e4-43ba-b7c9-80bbb930bcef
# DONE loading
# Loading %s... 4d3868c0-d11b-46d6-b4ab-5e52b550b759
# DONE loading
# Loading %s... 65fc6370-ff92-4df0-9134-da7a8759897a
# DONE loading
# Loading %s... 95e7245e-ce25-4944-9f4b-d1ab9b932e69
# DONE loading
# Loading %s... d7e73514-9dad-4c2f-8762-786788ac6984
# DONE loading
# Loading %s... a40b7de8-84cf-4012-abdf-7395b875aff5
# DONE loading
# Loading %s... 9b5a17bc-343d-4381-a7d3-6cd7224df1f1
# DONE loading
# Loading %s... 1e87915b-ba79-4d40-9dec-a7777ad64f99
# DONE loading
# Loading %s... D8A83E3D-D9B6-4ED4-8979-A514F8C6766E
# DONE loading
# Loading %s... fe732304-2d74-474b-85ae-b9daeca0a06e
# DONE loading
# Loading %s... 65afd0ab-40ec-4bc7-8856-3ff8c346e367
# DONE loading
# Loading %s... 3efd01dc-82fd-4b2d-a707-edf192a5c201
# DONE loading
# Loading %s... 8b357406-5e20-4c5b-ab5f-715dea8ea166
# DONE loading
# Loading %s... f0bb938f-6606-4da1-8488-5278e6c06f18
# DONE loading
# Loading %s... 350de76b-a9bd-44f8-8e63-7918fb50ceaf
# DONE loading
# Loading %s... 9ed09e7e-eb50-4879-9c12-df9f57bb51e1
# DONE loading
# Loading %s... 4a728a91-0c10-4a52-88df-609487321793
# DONE loading
# Loading %s... b8528e3b-c132-4de7-a673-2f624927e011
# DONE loading
# Loading %s... 0e262ff3-3b29-4a2b-a44b-39ed5f2e676d
# DONE loading
# Loading %s... 8383fdfa-ba94-47c2-9f16-7027912dce8d
# DONE loading
# Loading %s... d1e505d7-481f-4a6f-aead-578692fa94d5
# DONE loading
# Loading %s... 109fc26e-a37d-4001-bce1-f7d72caf97b5
# DONE loading
# Loading %s... a673cdb1-b8a3-4de7-bae3-188e3b9f5b53
# DONE loading
# Loading %s... 0d721125-f1c0-44e7-96fa-dd4773cf2445
# DONE loading
# Loading %s... 8c5b26e9-532e-4f97-89a3-480d9e685049
# DONE loading
# Loading %s... 09f87a41-9d1b-4a2f-bdaa-73afa83470f7
# DONE loading
# Loading %s... 68fb7e36-efee-4e07-a53c-06325d9e1e91
# DONE loading
# Loading %s... ca3a97ab-9b3e-4533-b46e-c2c6788e5635
# DONE loading
# Loading %s... ce109e1c-4280-499f-996b-c85c6bb57685
# DONE loading
# Loading %s... b5687d26-2776-43f6-9b31-44c94125a0e6
# DONE loading
# Loading %s... 490c5bb1-a4a4-4fff-a6f7-7da31f3bda5f
# DONE loading
# Loading %s... 20361528-0b8b-4e0a-ba3a-a3356271c75f
# DONE loading
# Loading %s... b266fdfd-e8b3-4bca-954a-7d0e2b0fdf25
# DONE loading
# Loading %s... f1e8f2ba-e5b1-4104-88be-1ed7f6f44904
# DONE loading
# Loading %s... 9c8271a4-b275-4d34-bef6-2ab260c1c4bf
# DONE loading
# Loading %s... 39f34b49-232d-480f-8fcb-342b2aea9733
# DONE loading
# Loading %s... d63505d3-b68c-4fc0-b9d5-ec67cd05f574
# DONE loading
# Loading %s... 1c06c349-ae7e-457c-a361-c1f348e933ce
# DONE loading
# Loading %s... 67375642-1dd9-40d5-9557-60666af89db3
# DONE loading
# Loading %s... 973b69eb-4b51-42ad-a9a0-69d01a7c8157
# DONE loading
# Loading %s... ed2dd249-298c-4f2d-be8f-820179dfa0a7
# DONE loading
# Loading %s... 7c19a825-dc16-4707-8f1f-4183354e1229
# DONE loading
# Loading %s... d92bccc9-a7d1-4bca-a3de-17b29f97c035
# DONE loading
# Loading %s... e643e918-6db1-4c0d-a3c6-07cfe0895f54
# DONE loading
# Loading %s... fcf602d1-fffb-4398-998c-05ce64b1e2a8
# DONE loading
# Loading %s... 93e701bc-aeb5-470a-8ff4-650804bce647
# DONE loading
# Loading %s... 19c808ad-7b07-433f-8f35-a80509344a08
# DONE loading
# Loading %s... 007d9f4d-643c-4f9f-8009-0f71428ab05e
# DONE loading
# Loading %s... a0be1a78-e915-49f0-b677-f5d227004236
# DONE loading
# Loading %s... 21300de2-68a8-4f39-a937-14d0ae44d887
# DONE loading
# Loading %s... 707d79e1-4543-4938-ae9c-044c46dacc30
# DONE loading
# Loading %s... 91feaa03-325b-4804-9f1b-088332a9884a
# DONE loading
# Loading %s... 4e8e0df9-0c1e-414d-860c-aedc9baa7159
# DONE loading
# Loading %s... 382ced5d-df5f-4ef6-a6cc-62363171533a
# DONE loading
# Loading %s... bb775eb6-032d-4958-946f-a5b608a5be43
# DONE loading
# Loading %s... a59cd9f3-d14b-4fca-b43b-ac2f8f7fc151
# DONE loading
# Loading %s... 448b4105-a8c6-46d6-b2ae-9dee9e9b5f14
# DONE loading
# Loading %s... 6299b8bb-cb88-4b8c-9431-14fd87f7741c
# DONE loading
# Loading %s... 21a624d0-8be3-4d2a-96b7-230b3d8fabeb
# DONE loading
# Loading %s... 8daac6d1-148c-4f4e-ba80-241e70edaf9e
# DONE loading
# Loading %s... 04c62755-1479-4809-9ff7-b4ef4f046120
# DONE loading
# Loading %s... a33b829e-5c61-4ee8-9737-5ab14fe3f7bf
# DONE loading
# Loading %s... 47bf0a29-19b1-4468-b0ec-bfde1f6593de
# DONE loading
# Loading %s... fa3bc46d-ca03-4d78-86a2-66c3f311941a
# DONE loading
# Loading %s... dbd62dae-abc1-419d-8322-045d266f0b45
# DONE loading
# Loading %s... 1e139b6c-35c7-4d54-8d37-cc2e812829db7
# DONE loading
# Loading %s... 5b096996-7d95-4588-a4db-a0ff311881da
# DONE loading
# Loading %s... f9975176-211a-42df-88a5-0eae3501a7ac
# DONE loading
# Loading %s... 1ab47202-a340-49ba-b47b-f53b7eeb1604
# DONE loading
# Loading %s... 9fe7c6c7-e931-4db5-80dd-7681d3da6d91
# DONE loading
# Loading %s... f3def7ad-015a-48bc-aaf2-b944069124cd
# DONE loading
# Loading %s... 72f09c64-d6f2-4d48-a138-6fa514803a86
# DONE loading
# Loading %s... 5B9E91C9-BB4A-4AF5-A78B-4B1649D02527
# DONE loading
# Loading %s... 8ab4f546-04b5-4c5d-8c36-b67bc1ebdd83
# DONE loading
# Loading %s... 20ffd6e1-49e1-413d-9b7a-f5e33fd497d7
# DONE loading
# Loading %s... fef42d93-a0d9-4d71-aa73-f02ed7171f7d
# DONE loading
# Loading %s... b2e2f632-8eff-4a3d-9467-0fb47c14fa5f
# DONE loading
# Loading %s... de26487d-676f-4dd1-b4b3-55d39ee37879
# DONE loading
# Loading %s... 02d01ff0-4622-4e8c-b363-caa0fa50ec64
# DONE loading
# Loading %s... b653c0f4-bbc5-4236-b6a3-e440ac4565ab
# DONE loading
# Loading %s... 00dff431-bb18-4a62-8fb6-828335fc1495
# DONE loading
# Loading %s... be7538d4-c8e6-44f4-910f-db1f4ec77a41
# DONE loading
# Loading %s... 9c66c399-83ee-4cd8-aadb-59ab36d52dbd
# DONE loading
# Loading %s... eebbe000-313f-4698-87b1-651a9e75f114
# DONE loading
# Loading %s... aaed27af-4717-4e50-8c8a-a5c7f87c0491
# DONE loading
# Loading %s... db68fdbf-110c-42c2-a729-2c2869b1ad49
# DONE loading
# Loading %s... 407b9eb8-7ca7-4006-b3e4-1358274f9b02
# DONE loading
# Loading %s... e4a45e48-5a54-409a-a104-884f77a6dc97
# DONE loading
# Loading %s... f685e2e7-e767-4dc2-b668-3516e9ccf8d5
# DONE loading
# Loading %s... ec9a0fcb-9942-4422-8808-0a0c8c5b823e
# DONE loading
# Loading %s... b7269ffc-d6e7-46fb-8c8b-af9931aa869b
# DONE loading
# Loading %s... 32ae0a92-8eca-4f25-8552-7600bc9370f5
# DONE loading
# Loading %s... 64c31dc7-33b5-45bb-b751-760160b49ad3
# DONE loading
# Loading %s... eaf1d043-b258-4b47-afce-9183e50aacb2
# DONE loading
# Loading %s... 2e39d104-3bf2-435d-8fb7-c58e11656862
# DONE loading
# Loading %s... 81CC1882-7054-4CCF-971B-17E05E1AB312
# DONE loading
# Loading %s... e9194248-72ef-4678-872f-99b59117edb5
# DONE loading
# Loading %s... 204490dc-7a25-41fe-93d5-db292c8951e9
# DONE loading
# Loading %s... a59546a1-c9a6-46f6-82dd-1a87b0e8813d
# DONE loading
# Loading %s... 908eafe6-f7b4-4003-b023-4df6f227d568
# DONE loading
# Loading %s... 5e44fa6c-354b-4727-b0dd-f7fa60d058ce
# DONE loading
# Loading %s... 09e85d0c-2551-40e7-a037-1f36fade0b0b
# DONE loading
# Loading %s... d3daa450-a728-4c8a-a38e-c4aa0d3d26cf
# DONE loading
# Loading %s... 3b10c86d-2560-4d0c-9f38-bac2ccbba480
# DONE loading
# Loading %s... 04180ef2-a3fe-4dcb-9c30-b8675845d392
# DONE loading
# Loading %s... 4fefb14c-a22d-4e6e-9820-3e73c079a7a2
# DONE loading
# Loading %s... 4307968f-4c6a-4b07-9b1b-3553fb1df154
# DONE loading
# Loading %s... 7136eafa-67cc-4703-8dbb-520d68ff9125
# DONE loading
# Loading %s... 1b2456c9-cc7e-482f-a6c5-e87bd2ecdaf9
# DONE loading
# Loading %s... 475ac9b0-fdcb-4276-bd0d-48170d72a9e0
# DONE loading
# Loading %s... c8fe7a7c-7235-44d0-bb72-b31ca8d1b9ed
# DONE loading
# Loading %s... 0394ccca-e0d1-494b-a67d-a7328fa13f88
# DONE loading
# Loading %s... 1611abed-851f-461b-b351-d242a41a3fe4
# DONE loading
# Loading %s... 17959ba8-1672-403e-854a-fba92e04bdb0
# DONE loading
# Loading %s... e04528be-94f6-4bc5-9485-9b71da7f4807
# DONE loading
# Loading %s... e04528be-94f6-4bc5-9485-9b71da7f4804
# DONE loading
# Loading %s... a7335048-e158-4657-8495-2f32cc86ca9e
# DONE loading
# Loading %s... 2c96f0bd-2ee8-47f7-9f0a-25039532dc3b
# DONE loading
# Loading %s... 430bb9e9-f76e-45ef-a23d-6c5cc16c3a94
# DONE loading
# Loading %s... eacb0b4f-9833-464f-b0a8-9d52872a59a2
# DONE loading
# Loading %s... 8b2f263c-ce65-405d-838f-64ee6fe0114a
# DONE loading
# Loading %s... c0112d11-a5ad-473c-bd83-ce6cd3d37d2c
# DONE loading
# Loading %s... 266b304d-06ba-43e1-b157-f63cd0b1797e
# DONE loading
# Loading %s... 57605124-495d-44fe-82ed-98dff8bb9c17
# DONE loading
# Loading %s... f88cfa0c-1192-443d-bd7c-0dfa5b9f9c4b
# DONE loading
# Loading %s... 3502cca7-ee24-4cbe-8d84-0210e9be406e
# DONE loading
# Loading %s... e34ea993-f4f1-46c0-b78f-e87332e1685e
# DONE loading
# Loading %s... f844e84d-dab0-4fba-a9d4-1f4341fd8ae2
# DONE loading
# Loading %s... b067a370-d510-480e-8e6e-975d0608be4b
# DONE loading
# Loading %s... d7ffbbf1-db2a-46eb-ad37-fe999b7f1843
# DONE loading
# Loading %s... c551ffcb-cba4-456a-9b16-e0ea541417aa
# DONE loading
# Loading %s... 9fdef120-3a00-4631-bcc7-545b598437ef
# DONE loading
# Loading %s... 9ebeadc5-42d4-4202-b0f9-2a4f607ee3fc
# DONE loading
# Loading %s... b1d5ed13-e5db-42d0-88fe-7bae2ec7e18c
# DONE loading
# Loading %s... 876b4b86-82af-4135-aabb-f37868775130
# DONE loading
# Loading %s... 0089a052-0ffa-47ba-a8c0-9fad7f1ae0cc
# DONE loading
# Loading %s... 2de8f3b5-35b7-48e5-bd25-7997f021cd4c
# DONE loading
# Loading %s... d970b2ad-9487-45ca-b0d1-63736ef14ab6
# DONE loading
# Loading %s... 509f50b7-1745-44e4-9571-5995b23518ca
# DONE loading
# Loading %s... 3ed64bfd-33b1-43a9-b794-5e5cde9d8d36
# DONE loading
# Loading %s... a0f4e06a-44ef-4cce-89bd-d92cecc7dfe6
# DONE loading
# Loading %s... 5535b19f9ca84f74b3576fe0a56c3aa5
# DONE loading
# Loading %s... 66862b21-9f41-445b-85d8-73bfd2c8a2ca
# DONE loading
# Loading %s... fb19b0a4-779e-11ec-90d6-0242ac120003
# DONE loading
# Loading %s... bebb4928-f4b8-4be7-928d-223cf77475c0
# DONE loading
# Loading %s... 158f04e1-284b-4f2d-a55f-eb7ddc637b9f
# DONE loading
# Loading %s... 96427898-c13f-4630-bd17-ee281c8e5f98
# DONE loading
# Loading %s... 09b50a1f-9206-4fef-a7d8-efd6ec0dca1f
# DONE loading
# Loading %s... fd371113-6fc5-4790-bd13-788fc7231400
# DONE loading
# Loading %s... a6ff04dc-bc68-4339-968e-8341b62b6ce9
# DONE loading
# Loading %s... bb684132-f2ca-481a-9582-bd3de6f5c3e6
# DONE loading
# Loading %s... cf71854a-9e7b-4b5f-90ce-3274ad327e72
# DONE loading
# Loading %s... cd208e44-a85f-408a-8f5e-dcec5f85c962
# DONE loading
# Loading %s... 87095323-a508-44c8-95b1-5583e8e14167
# DONE loading
# Loading %s... 13a51673-7133-48f3-bdfe-e6a8309de690
# DONE loading
# Loading %s... 4e8587f8-9825-442b-b76f-330450c59548
# DONE loading
# Loading %s... 939d3352-727a-4c3f-928e-2d3a9cca911f
# DONE loading
# Loading %s... 9601e3e1-bb2f-4b1d-b8d7-8d806b3039e2
# DONE loading
# Loading %s... 73719bfa-8c1e-4607-8b9c-09a6e445d436
# DONE loading
# Loading %s... 89d1da80-c72a-11ec-9d64-0242ac120002
# DONE loading
# Loading %s... 4f1b36d9-67b5-4622-a851-e80f4e137e4f
# DONE loading
# Loading %s... c1eed465-f9bf-4a63-84c5-87dd66c72318
# DONE loading
# Loading %s... 6a60b3dd-cb30-4a9b-8b94-9197e17d4ba5
# DONE loading
# Loading %s... 438838d1-a936-4789-9d1c-c929788be1eb
# DONE loading
# Loading %s... ed4b2246-1e63-4911-b4b8-b62ebff8a932
# DONE loading
# Loading %s... 1df1712d-52c5-4891-9de1-bdecb1193b94
# DONE loading
# Loading %s... 9cabd554-398b-4dd4-8a36-5fe46c7cda94
# DONE loading
# Loading %s... c8d87142-595a-11eb-ae93-0242ac130002
# DONE loading
# Loading %s... 03f5af75-44df-4567-b4fd-3332cb4e052e
# DONE loading
# Loading %s... f0b1d404-83b8-4796-ac5f-748597e9df5e
# DONE loading
# Loading %s... 864c77db-f273-4a11-8104-8149f3f9566f
# DONE loading
# Loading %s... 9ce14ba6-741e-4ca5-9879-f2a9f3adf958
# DONE loading
# Loading %s... d8d6d1b6-e860-437a-9e51-f4472b428cc7
# DONE loading
# Loading %s... e9d0e39e-b167-4dd7-b2a2-b9ba921da487
# DONE loading
# Loading %s... b9e0c182-c252-4d91-aae8-005d6d89d68b
# DONE loading
# Loading %s... 307e33be-6bd7-42a0-b4d7-74b244dbdf79
# DONE loading
# Loading %s... 981faa0b-dd13-481f-aed0-c0106cbd31da
# DONE loading
# Loading %s... f603db7f3dfe45e3a502ba9e94cfe4ad
# DONE loading
# Loading %s... 53dd7420-a83f-4198-a63c-7aa7cb0b4416
# DONE loading
# Loading %s... 1ea2aa9b-44d5-43b9-9b47-73ab6b4de86c
# DONE loading
# Loading %s... ac9d4374-002f-4be5-9c45-ae246ec65191
# DONE loading
# Loading %s... 1f8b1c03-720b-4dd6-b8f5-c631931dcc10
# DONE loading
# Loading %s... f251ad5c-eccc-40f2-a9d8-6ea05fe38e6a
# DONE loading
# Loading %s... 72b6ab5a-f674-4872-9c80-bb4dcb54915f
# DONE loading
# Loading %s... 8aa81736-9387-4a42-ab7a-e69eaf53fb8c
# DONE loading
# Loading %s... 389c37a8-24f9-45a1-8a47-9d2b996a67da
# DONE loading
# Loading %s... cf5f29ba-97d1-42e6-9ea3-4621ff6485b1
# DONE loading
# Loading %s... 6f87b3b8-1396-49ab-a2d0-a26bef7ddb9f
# DONE loading
# Loading %s... a3dea8d3-2b75-4ffc-932b-1358da5bc1f1
# DONE loading
# Loading %s... 66862b21-9f41-445b-85d8-73bfd2c8a2ca
# DONE loading
# Loading %s... bd76ebc1-8b9e-48a3-81f2-220825c366a1
# DONE loading
# Loading %s... 14162e03-c31b-4eda-92a1-3ac5a125ad25
# DONE loading
# Loading %s... 00a94d5e-7fce-4806-a873-a9f77fd58cdf
# DONE loading
# Loading %s... f500d77c-028f-4366-a285-1d3074b9d648
# DONE loading
# Loading %s... 5db23135-2470-428b-98ab-dd33f3c8a5cf
# DONE loading
# Loading %s... dd7d7fe8-e354-11eb-88f7-f923b9ff781d
# DONE loading
# Loading %s... fc913e87-36e8-400f-ac60-05ae8f512440
# DONE loading
# Loading %s... d5711d39-7d15-4fac-9d6d-e81c2feae401
# DONE loading
# Loading %s... 73263d94-f8e6-41a2-9e28-0db8132d584e
# DONE loading
# Loading %s... 37231272-8d44-4c8e-8d75-0758790a53a9
# DONE loading
# Loading %s... 9d9f39ab-b84b-439f-b0fc-024ad885c1ad
# DONE loading
# ...
# Loading %s... 0aa90e05-6d19-4804-846e-c8d8564cc402
# DONE loading
# Loading %s... b11f5efc-a95c-465f-a0c7-521bc3c41349
# DONE loading
# Loading %s... b11f5efc-a95c-465f-a0c7-521bc3c41349
# DONE loading
# Loading %s... 2b8e1cd8-301a-4fec-be7a-9e61946c21b8
# DONE loading
# Loading %s... c5040d49-9511-42c3-8585-90a0bb45bb9f
# DONE loading
# Loading %s... a633f94c-f9e4-4184-a4b9-ccad12dd40f0
# DONE loading
# Loading %s... 7f1afeea-1c73-4e84-af08-8c9cd0fe27d5
# DONE loading
# Loading %s... 8d126277-6e4a-4f11-bd20-69755459b990
# DONE loading
# Loading %s... 8d126277-6e4a-4f11-bd20-69755459b990
# DONE loading
# Loading %s... 86a33091-37a8-4c62-9e2c-1700e89fc265
# DONE loading
# Loading %s... 5705b692-227b-4275-86ed-25232b666507
# DONE loading
# Loading %s... 224526a5-09a4-4895-9b8b-40e8984a44d3
# DONE loading
# Loading %s... 5b6de476-1f06-45d9-84c8-30f94daba7ef
# DONE loading
# Loading %s... 5b6de476-1f06-45d9-84c8-30f94daba7ef
# DONE loading
# Loading %s... 6d89c6b6-b177-4a7b-843e-73b0b5101efc
# DONE loading
# Loading %s... b9eac1d1-d508-46c3-bd3b-3fade82a46fc
# DONE loading
# Loading %s... dbc55701-2e03-47bb-b164-9f0ed255f7aa
# DONE loading
# Loading %s... 4a2850ea-2132-4425-9241-fa1f7ce1e931
# DONE loading
# Loading %s... 4a2850ea-2132-4425-9241-fa1f7ce1e931
# DONE loading
# Loading %s... d53a99dd-dbbb-4e05-ae9a-b1249487bb0d
# DONE loading
# Loading %s... 73edb398-0c88-4d74-a5b0-141a1c999e78
# DONE loading
# Loading %s... 73edb398-0c88-4d74-a5b0-141a1c999e78
# DONE loading
# Loading %s... 8d86b64a-99eb-41e6-bf09-7c3c9ab59164
# DONE loading
# Loading %s... 1baf6f85-625c-4790-ba72-e83a7af35dc4
# DONE loading
# Loading %s... e6beadda-22e5-4c46-a486-050c0aeebd0e
# DONE loading
# Loading %s... b9878572-1286-468f-9951-4422acc61c69
# DONE loading
# Loading %s... b9878572-1286-468f-9951-4422acc61c69
# DONE loading
# Loading %s... 6669d406-1932-4c73-aaf7-4909808e90d8
# DONE loading
# Loading %s... 6669d406-1932-4c73-aaf7-4909808e90d8
# DONE loading
# Loading %s... 37ea84a1-ac63-4441-86d7-28341d5def48
# DONE loading
# Loading %s... 0fa275b8-0b9d-4266-a684-728d8e4720cd
# DONE loading
# Loading %s... eac1d2a2-2955-42ff-84e3-96a9aa40fc8c
# DONE loading
# Loading %s... 870706a0-9b75-4b48-a58c-036f3c73c7cb
# DONE loading
# Loading %s... 870706a0-9b75-4b48-a58c-036f3c73c7cb
# DONE loading
# Loading %s... 871423e9-0f0c-4970-9645-bbdc7caface0
# DONE loading
# Loading %s... 871423e9-0f0c-4970-9645-bbdc7caface0
# DONE loading
# Loading %s... bb3560f9-6809-4b82-8128-5955dfcb888e
# DONE loading
# Loading %s... 2adb8419-658c-43c7-bea0-eda61b69423c
# DONE loading
# Loading %s... 95d3e0fc-98c2-4a61-be48-7d17d2ae4a59
# DONE loading
# Loading %s... 95d3e0fc-98c2-4a61-be48-7d17d2ae4a59
# DONE loading
# Loading %s... 93913850-014c-4286-8640-8e588331889c
# DONE loading
# Loading %s... 93913850-014c-4286-8640-8e588331889c
# DONE loading
# Loading %s... b6c7e518-f296-40e6-a235-b192435c79af
# DONE loading
# Loading %s... 665b7d87-ceb9-438d-898f-60d7feaedc73
# DONE loading
# Loading %s... e5fa1b5c-f9a0-49a4-ab2b-84e3ac3725d2
# DONE loading
# Loading %s... e5fa1b5c-f9a0-49a4-ab2b-84e3ac3725d2
# DONE loading
# Loading %s... a0accfc1-25b8-4e21-81fd-6e2a42bd3e8f
# DONE loading
# Loading %s... af434ac4-e1ca-44a8-8bb8-5a644dd35faf
# DONE loading
# Loading %s... af434ac4-e1ca-44a8-8bb8-5a644dd35faf
# DONE loading
# Loading %s... 05b0a181-b0db-4554-888c-f78a7fa3ff45
# DONE loading
# Loading %s... 05b0a181-b0db-4554-888c-f78a7fa3ff45
# DONE loading
# Loading %s... 86ba11c7-5a72-4c9d-8a98-dca781caadd9
# DONE loading
# Loading %s... f0b26b58-db86-4c69-b339-8896fd929d18
# DONE loading
# Loading %s... 596818b3-4b43-43d5-a0c4-63accc68240e
# DONE loading
# Loading %s... 205f4a4b-ec04-4968-bf05-b48ff0549c3a
# DONE loading
# Loading %s... 7710f54d-ad6c-46c9-aac0-b99bf0e845f3
# DONE loading
# Loading %s... 816f08f6-cf2d-425f-9735-50a47d06467f
# DONE loading
# Loading %s... bc3cb707-cb8a-41f1-9637-cac74d6be34d
# DONE loading
# Loading %s... bc3cb707-cb8a-41f1-9637-cac74d6be34d
# DONE loading
# Loading %s... 60f8049c-49a8-42ec-86eb-4767f976153a
# DONE loading
# Loading %s... fcbd588d-a8f1-46f1-9725-365c357f2f02
# DONE loading
# Loading %s... db0e845d-f4e7-46a1-be8c-36ed877104f1
# DONE loading
# Loading %s... db0e845d-f4e7-46a1-be8c-36ed877104f1
# DONE loading
# Loading %s... 4e02a9b0-2dca-4883-93d3-76f587700832
# DONE loading
# Loading %s... a1c67347-3e79-4aea-a782-1cfea228fc39
# DONE loading
# Loading %s... a1c67347-3e79-4aea-a782-1cfea228fc39
# DONE loading
# Loading %s... fb295921-4325-473f-954b-3e9a3ac9bd18
# DONE loading
# Loading %s... dd385c39-5417-4a47-8117-461af662437e
# DONE loading
# Loading %s... a760876c-d24c-46c8-9842-37295b5b7216
# DONE loading
# Loading %s... f88a3741-db20-48a3-8e14-e3430f99ec77
# DONE loading
# Loading %s... f88a3741-db20-48a3-8e14-e3430f99ec77
# DONE loading
# Loading %s... 852a0b87-3845-450b-9acb-cdea93a45a59
# DONE loading
# Loading %s... b395ddf1-1be8-4fea-9104-3eb723e15653
# DONE loading
# Loading %s... b395ddf1-1be8-4fea-9104-3eb723e15653
# DONE loading
# Loading %s... 15ed906b-7ba2-4629-964a-455b98ec0fdd
# DONE loading
# Loading %s... 6d30a8d6-083a-4d0a-907c-33e51102276a
# DONE loading
# Loading %s... ff252c08-b24c-465f-8f78-2b05f0c2898c
# DONE loading
# Loading %s... 02833a2c-1b96-441e-a5fa-cab1c08d719d
# DONE loading
# Loading %s... 53492d4a-48ce-4a56-9492-ff30b3088528
# DONE loading
# Loading %s... d1a75f22-24b9-4e37-bc5a-e6a588678809
# DONE loading
# Loading %s... bc3eeb36-8d94-4800-a5ee-6b4d38e429b2
# DONE loading
# Loading %s... a6672d9f-92fb-4ac4-bee7-a909d535d638
# DONE loading
# Loading %s... 06dabe9c-6a0f-47e5-9e02-35f9e3e8bfea
# DONE loading
# Loading %s... dcf28a5b-719f-485b-9c4a-c83391bd0352
# DONE loading
# Loading %s... 87582aef-00c4-4b3d-b3ca-a0152c5d339b
# DONE loading
# Loading %s... 0ffe1791-5dfc-4f3c-8497-e6a1531b47bf
# DONE loading
# Loading %s... 914d38f6-9b2b-4e35-8935-4454404a98a2
# DONE loading
# Loading %s... 4166f5eb-3aa9-41da-8bd2-a21dbebca889
# DONE loading
# Loading %s... 4166f5eb-3aa9-41da-8bd2-a21dbebca889
# DONE loading
# Loading %s... b3d225d5-c098-440d-b732-31466745c40f
# DONE loading
# Loading %s... b3d225d5-c098-440d-b732-31466745c40f
# DONE loading
# Loading %s... 8a61f735-1ce4-444a-86d4-87cbef8b0a67
# DONE loading
# Loading %s... 05d556a5-95e7-4cc5-8f25-54b0362d9c98
# DONE loading
# Loading %s... 497cef87-6856-4903-85e5-dbc9d5e66928
# DONE loading
# Loading %s... 7839e147-b568-4eda-b4cc-7cb2a2902309
# DONE loading
# Loading %s... fb014167-ba90-451f-b1a8-77f7a322bda6
# DONE loading
# Loading %s... e3abed08-0a42-41d2-9ab1-86ad52ffee4d
# DONE loading
# Loading %s... e3abed08-0a42-41d2-9ab1-86ad52ffee4d
# DONE loading
# Loading %s... ba94f57a-d57e-4b0b-9050-b5be67cd0c1f
# DONE loading
# Loading %s... dcb9115f-b0e3-4051-82e1-9e67841ff35a
# DONE loading
# Loading %s... 2c8f3620-e9c8-46b5-bc9a-3db25aa5511d
# DONE loading
# Loading %s... a10292a5-4963-4ad0-bf0f-245414c4d757
# DONE loading
# Loading %s... b70ffe6f-1ab9-42c0-b376-776a3cd56f3a
# DONE loading
# Loading %s... 67c58ec6-075c-4bf3-89a8-d45cb2567cc5
# DONE loading
# Loading %s... 67c58ec6-075c-4bf3-89a8-d45cb2567cc5
# DONE loading
# Loading %s... c6dfdc40-cdc3-41af-8259-c09e431ebadf
# DONE loading
# Loading %s... cbee22dd-507a-49e0-8571-004daaf91fc6
# DONE loading
# Loading %s... d63dc0c9-1b01-40c3-9b52-7de74a02df56
# DONE loading
# Loading %s... b35b7681-3136-430b-9ff0-8d77b38d5a13
# DONE loading
# Loading %s... 87a1ff39-8824-454e-a021-4cebbd907775
# DONE loading
# Loading %s... 87a1ff39-8824-454e-a021-4cebbd907775
# DONE loading
# Loading %s... 2f2c8f95-3315-4d43-a8c0-bb74451112b5
# DONE loading
# Loading %s... df864cd6-a5ae-4969-8529-9e61cfeb9f81
# DONE loading
# Loading %s... 2cb15d24-749c-4961-89ba-3095f42d4748
# DONE loading
# Loading %s... 4dde5bdb-e2f0-47c5-b3d8-a97a587c89c6
# DONE loading
# Loading %s... 723c5f5c-7ea1-477f-9104-3e1914867408
# DONE loading
# Loading %s... 52d804ec-db7f-4329-b356-c7d68de9b5f3
# DONE loading
# Loading %s... 430319ac-ca6c-4119-a037-67c85965ca88
# DONE loading
# Loading %s... 430319ac-ca6c-4119-a037-67c85965ca88
# DONE loading
# Loading %s... 8868b3c6-5354-4b35-bbbd-819b24f53e59
# DONE loading
# Loading %s... 164c3fa1-35c4-4b49-b6f5-3ecdc1db008e
# DONE loading
# Loading %s... 164c3fa1-35c4-4b49-b6f5-3ecdc1db008e
# DONE loading
# Loading %s... fd23bce8-06be-4634-bae2-0c22394b48e3
# DONE loading
# Loading %s... 65363702-c4ad-449a-a117-6f89750c4fa1
# DONE loading
# Loading %s... 5e1b829e-b34e-4b50-92d6-1d578f0cecb1
# DONE loading
# Loading %s... 46f0da80-1dbc-4931-8d66-f8c1a1b6d6b2
# DONE loading
# Loading %s... 97c3d22e-a50e-4f31-946b-239acfafb174
# DONE loading
# Loading %s... 30092d1a-95ae-4207-b2a6-59245ab06159
# DONE loading
# Loading %s... b63055e3-f7b8-4a0f-a908-27c3dd21e624
# DONE loading
# Loading %s... b63055e3-f7b8-4a0f-a908-27c3dd21e624
# DONE loading
# Loading %s... 54c8f6cc-3d14-4c83-9d87-e93e1318f7c8
# DONE loading
# Loading %s... 7ef120d5-951b-4639-aeb9-be91c7caaa2a
# DONE loading
# Loading %s... 1bd344b2-067c-460e-9a19-57d5ed0b5715
# DONE loading
# Loading %s... 1f56b671-f830-4885-9ac0-ddeaeb424e18
# DONE loading
# Loading %s... 9f028453-57d4-438d-844c-f21b4211e0ab
# DONE loading
# Loading %s... caee358a-f5ba-49e8-b45e-029092879418
# DONE loading
# Loading %s... 94f17e93-bbf8-42f1-982b-57bd164bbf04
# DONE loading
# Loading %s... 8a8c88d0-9ef7-4030-9888-30c23632c893
# DONE loading
# Loading %s... b5842b87-9a53-423a-b3a2-215bb3585996
# DONE loading
# Loading %s... 1aab83f4-ed55-4a81-8e12-a8c4f40a84ff
# DONE loading
# Loading %s... 1b6493c3-30c6-429c-9ced-cba8af346387
# DONE loading
# Loading %s... 1b6493c3-30c6-429c-9ced-cba8af346387
# DONE loading
# Loading %s... c0851272-cfc6-4b55-ac8e-3bcc98f89f49
# DONE loading
# Loading %s... 6c5d80a8-84b9-4da2-a719-86ee58f2654a
# DONE loading
# Loading %s... f37902a6-2abd-4d99-bc51-e538eddfbfb4
# DONE loading
# Loading %s... 026d1c49-c698-48c4-b80b-3f3a6f36e9ca
# DONE loading
# Loading %s... b75eb361-3ff6-496c-8629-d6f977dadc74
# DONE loading
# Loading %s... 958f0ee7-fbfc-45bc-a802-9b06e1626d69
# DONE loading
# Loading %s... be0f6e64-44ee-4194-96dd-a8cde1b5f336
# DONE loading
# Loading %s... be0f6e64-44ee-4194-96dd-a8cde1b5f336
# DONE loading
# Loading %s... a60957ce-e609-429c-a32e-12b734a77c7c
# DONE loading
# Loading %s... f4f79b77-0682-41a7-927b-bae57967c5e3
# DONE loading
# Loading %s... bacce3a8-5bf2-4c2e-aec1-e03176910c02
# DONE loading
# Loading %s... 391855be-df0f-49c2-902a-9d373cca217f
# DONE loading
# Loading %s... e91d9ba7-e1af-44c4-9b80-b6aba05cecaa
# DONE loading
# Loading %s... 074f9968-f249-483f-8bb8-282500326055
# DONE loading
# Loading %s... b0c3999b-a15b-408e-9b94-356fb44405a0
# DONE loading
# Loading %s... 62954073-e0b4-4300-addd-53676a9ead63
# DONE loading
# Loading %s... dfed69f8-1ad8-4984-b4d7-1586200ecf7d
# DONE loading
# Loading %s... a5d7c5e6-5e76-4299-94fb-d5ea46f9e96c
# DONE loading
# Loading %s... a5c3ee4a-7f95-4f98-805f-73b76b7fb27c
# DONE loading
# Loading %s... 1dc3d6e0-9cfd-4ce6-8666-56a810f97951
# DONE loading
# Loading %s... 1dc3d6e0-9cfd-4ce6-8666-56a810f97951
# DONE loading
# Loading %s... a2f88c7c-c262-48c8-960c-a2dcab791c77
# DONE loading
# Loading %s... b7453f8a-161a-4bf9-bfa4-4a10f3d09b94
# DONE loading
# Loading %s... b7453f8a-161a-4bf9-bfa4-4a10f3d09b94
# DONE loading
# Loading %s... 2c521dfb-e1c5-4e39-9af9-023304d70ee7
# DONE loading
# Loading %s... e02f3115-51d9-4ae9-914a-bf481ec8a843
# DONE loading
# Loading %s... 148856d2-071a-4251-b504-cd60ad274362
# DONE loading
# Loading %s... 5a45050f-93b2-4e8d-ad5e-9dc3751adf37
# DONE loading
# Loading %s... 9f645b9a-c6e2-495c-8443-f7f1216750ba
# DONE loading
# Loading %s... fac1d829-477b-4363-98be-e12b20773a35
# DONE loading
# Loading %s... 52a2d5fe-1db2-46ff-af8b-2dd5179fb20b
# DONE loading
# Loading %s... 2698308f-e918-4434-bfeb-fb0812bc237f
# DONE loading
# Loading %s... 97f0ddf6-07f8-45b1-b74e-ef8070b80d97
# DONE loading
# Loading %s... d39f7f50-e353-4434-b7a2-b0166dbaa127
# DONE loading
# Loading %s... e8d3c1f7-4050-4376-8f8a-7f09589b09f3
# DONE loading
# Loading %s... 9ce08c33-2e0d-4445-b12d-44da3dd3825c
# DONE loading
# Loading %s... 87dc2ada-5a12-43cd-9caf-38efeded8061
# DONE loading
# Loading %s... 0b579930-76c5-4385-b4ca-dbfabb45afcf
# DONE loading
# Loading %s... 3ae37e0d-60cf-4e9b-890b-bee42994bc3f
# DONE loading
# Loading %s... 3ae37e0d-60cf-4e9b-890b-bee42994bc3f
# DONE loading
# Loading %s... 0cb38417-5837-4896-b738-f4b19742e1c9
# DONE loading
# Loading %s... 73b8e3a5-e24b-423b-b7ec-2a9266c6352a
# DONE loading
# Loading %s... 73b8e3a5-e24b-423b-b7ec-2a9266c6352a
# DONE loading
# Loading %s... 47eac3e2-376d-4262-9de4-9e16e054b28f
# DONE loading
# Loading %s... f2a2d773-3593-4391-a67f-4e9e157b86b5
# DONE loading
# Loading %s... 5705ba5c-af3b-4cb5-a327-d430d57bd9cc
# DONE loading
# Loading %s... 5705ba5c-af3b-4cb5-a327-d430d57bd9cc
# DONE loading
# Loading %s... ff2fbf5f-72bb-4c76-acfa-adbd50c46eb7
# DONE loading
# Loading %s... ff2fbf5f-72bb-4c76-acfa-adbd50c46eb7
# DONE loading
# Loading %s... 5ea132db-190c-4c33-9886-ee286db069e5
# DONE loading
# Loading %s... bdae8773-190a-4645-a342-7da30a4b0012
# DONE loading
# Loading %s... 4d4c28c8-8eb9-4459-a0a2-a4999ce28aea
# DONE loading
# Loading %s... c26b71a5-2e97-4529-ae9c-93dfa37dabb3
# DONE loading
# Loading %s... 5f847fb7-1fc6-4479-8823-510f056ca062
# DONE loading
# Loading %s... 5425f426-74f1-48c7-8691-768a1ac884ea
# DONE loading
# Loading %s... eb107590-dd7a-41ca-b639-44b2972e9573
# DONE loading
# Loading %s... eb107590-dd7a-41ca-b639-44b2972e9573
# DONE loading
# Loading %s... 06cf0ed1-2076-4e62-8a54-2b2634db7bf1
# DONE loading
# Loading %s... c86b8667-3dbb-4d93-8276-ef6e553a1698
# DONE loading
# Loading %s... c86b8667-3dbb-4d93-8276-ef6e553a1698
# DONE loading
# Loading %s... 2f9fda70-fab6-4e5d-817b-27882fb5a38d
# DONE loading
# Loading %s... f7c9599a-1e37-4506-a16b-3ba8ffa9e530
# DONE loading
# Loading %s... cf0701aa-a514-446d-be76-bcbfe3571d5d
# DONE loading
# Loading %s... cf0701aa-a514-446d-be76-bcbfe3571d5d
# DONE loading
# Loading %s... c153ae2e-7f59-4078-8c89-378bc70927d2
# DONE loading
# Loading %s... 1f372c0d-a54b-4d8c-a99d-5a8fe1829dfa
# DONE loading
# Loading %s... 627aaf66-33d2-4362-9c3f-9b936df6d1ef
# DONE loading
# Loading %s... 62a8a076-ef27-42ef-9dc0-eb3dd44076ba
# DONE loading
# Loading %s... a8b0a61a-f840-431c-9a78-39c2cb17d1a7
# DONE loading
# Loading %s... f5545eaf-7e2f-424a-b4cd-61d5a95cc44f
# DONE loading
# Loading %s... a0eccf7b-3efb-4c5f-bb1c-4049202b1e0f
# DONE loading

# %%
print(loadChangeLog)
# Out:
# None
